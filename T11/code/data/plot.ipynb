# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Data = np.loadtxt("./merge-1e3.dat", skiprows=6)
Data = np.loadtxt("./merge-1e3-vertical.dat", skiprows=6)

# %%
Time = Data[:, 0]
Pos = Data[:, 1:]
InitialPos = Pos[0].reshape(2500, 3)
MiddlePos = Pos[10].reshape(2500, 3)
FinalPos = Pos[-1].reshape(2500, 3)

# %%
scale = 50

plt.figure(figsize=(6, 6))

# plt.scatter(InitialPos[1000:1250, 0], InitialPos[1000:1250, 2], s=1, label="galaxy 1: initial pos")
# plt.scatter(InitialPos[-250:, 0], InitialPos[-250:, 2], s=1, label="galaxy 2: initial pos")

plt.scatter(MiddlePos[1000:1250, 0], MiddlePos[1000:1250, 2], s=1, label="galaxy 1: middle pos")
plt.scatter(MiddlePos[-250:, 0], MiddlePos[-250:, 2], s=1, label="galaxy 2: middle pos")

# plt.scatter(FinalPos[1000:1250, 0], FinalPos[1000:1250, 2], s=1, label="galaxy 1: final pos")
# plt.scatter(FinalPos[-250:, 0], FinalPos[-250:, 2], s=1, label="galaxy 2: final pos")

plt.xlabel("x (kparsec)")
plt.ylabel("z (kparsec)")


plt.xlim(-20, 60)
plt.ylim(-15, 15)

# plt.xlim(-400, -250)
# plt.ylim(-80, 50)

plt.legend()
plt.grid()
plt.savefig("vertical-galaxies-middle.png", dpi=300)
plt.show()

# %%
Distance = np.linalg.norm(MassiveParticlePos, axis=1)
InitialPos = Data[0, 1:].reshape(1001, 3)

# %%
plt.figure(figsize=(6,6))
plt.scatter(InitialPos[:-1, 0], InitialPos[:-1, 1], s=5, label="halo particles")
plt.scatter(InitialPos[-1, 0], InitialPos[-1, 1], s=100, label=r"$M_{body}$")
plt.plot(MassiveParticlePos[:, 0], MassiveParticlePos[:, 1], '--k', alpha=.5, lw=.8, label=r"$M_{body}$ orbit")

plt.xlabel("x (kparsec)")
plt.ylabel("y (kparsec)")

plt.xlim(-6, 6)
plt.ylim(-6, 6)
# plt.axis("equal")
plt.legend()
plt.grid()
# plt.savefig("orbit.png", dpi=300)
plt.show()

# %%
plt.plot(Data[:, 0], Distance)
plt.xlabel(r"t  (1.2$\times 10^6$ year)")
plt.ylabel("distance (kparsec)")
plt.grid()
plt.savefig("distance.png", dpi=300)
plt.show()

# %%
time = Data[:, 0]
pos = Data[:, 1:]
r = np.linalg.norm(pos, axis=1)

# %%
file_name = {r"\rho = \rho_0 / 0.5^2": "./sphere-0.5tff.dat", r"\rho = \rho_0 / 0.7^2": "./sphere-0.7tff.dat", r"\rho = \rho_0 / 0.85^2": "./sphere-0.85tff.dat",
             r"\rho = \rho_0 / 1^2": "./sphere-1tff.dat", r"\rho = \rho_0 / 1.5^2": "./sphere-1.5tff.dat", r"\rho = \rho_0 / 2^2": "./sphere-2tff.dat"}

for file in file_name:
    Data = np.loadtxt(file_name[file], skiprows=6, usecols=range(4))
    time = Data[:, 0]
    pos = Data[:, 1:]
    r = np.linalg.norm(pos, axis=1)
    plt.plot(time, r, lw=1, label=file)

plt.ylim(0, 5)
plt.xlabel(r"t (year)")
plt.ylabel("r (AU)")

plt.legend(loc=1)
plt.grid()

# plt.savefig("tracer-particle.png", dpi=300)
plt.show()

# %%
file_name = {r"\rho = \rho_0 / 0.5^2": "./sphere-0.5tff.dat", r"\rho = \rho_0 / 0.7^2": "./sphere-0.7tff.dat",
             r"\rho = \rho_0 / 0.85^2": "./sphere-0.85tff.dat", r"\rho = \rho_0 / 1^2": "./sphere-1tff.dat",
             r"\rho = \rho_0 / 1.5^2": "./sphere-1.5tff.dat", r"\rho = \rho_0 / 2^2": "./sphere-2tff.dat"}

rho = np.array([.5, .7, .85, 1., 1.5, 2])
rho = np.ones_like(rho) / (rho * rho) * 0.95
tff = np.array([])

for file in file_name:
    Data = np.loadtxt(file_name[file], skiprows=6, usecols=range(4))
    time = Data[:, 0]
    pos = Data[:, 1:]
    r = np.linalg.norm(pos, axis=1)
    min_index = np.argmin(r)
    tff = np.append(tff, time[min_index])

x = np.linspace(0.5, 2, 30)
y = np.sqrt(3*np.pi / 32 / 39.47) * x

plt.plot(np.power(rho, -0.5), tff, "-o", label="simulation data")
plt.plot(x, y, 'k--', alpha=.5, label=r"$t_{ff}=\sqrt{\frac{3\pi}{32G}}\times \rho^{-0.5}$")

plt.xlabel(r"$\rho^{-0.5}$")
plt.ylabel(r"$t_{ff}$ (year)")
plt.legend()
plt.grid()

# plt.savefig("tff-relation.png", dpi=300)
plt.show()

# %%
Data = np.loadtxt("./sphere-1tff.dat", skiprows=6, usecols=range(6*10+1))
time = Data[:, 0]
pos = Data[:, 1:]
r = np.zeros((len(pos), 10))

for i in range(10):
    r[:, i] = np.linalg.norm(pos[:, i*6:i*6+3], axis=1)

min_index = np.argmin(np.linalg.norm(r, axis=1))
min_index = np.argmin(r[:, 0]) + 2

# %%
for i in range(10):
    plt.plot(time[:min_index], r[:min_index, i], lw=1)

plt.vlines(0.088, 0, 4.1, ls='--', colors='black', alpha=.5, label=r"theoretical $t_{ff}$")

plt.ylim(0, 4.1)
plt.xlabel("time (year)")
plt.ylabel("r (AU)")

plt.grid()
plt.legend()

plt.savefig("5-particles.png", dpi=300)
plt.show()

# %%
Data = np.loadtxt("./sphere-1tff.dat", skiprows=6, max_rows=1)

# %%
pos = Data[1:].reshape(257,6)
pos = pos[:, :3]

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(pos[:, 0], pos[:, 1], pos[:, 2])
# ax.set_xlim3d(-3,3)
# ax.set_ylim3d(-3,3)
# ax.set_zlim3d(-3,3)
plt.show()

# %%
plt.axis("equal")

plt.scatter(pos[:, 0], pos[:, 1])

plt.grid()

plt.savefig("initial-projection.png", dpi=300)
plt.show()
